# %% [markdown]
# <a href="https://colab.research.google.com/github/123hawaa/Automate-the-Boring-Stuff-with-Python/blob/master/chapter_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FUNCTIONS

# %%
#Hello function
def hello():
  print("hello world")
  print("hello girles ")
  print("hello From group 4")

# %%
hello()
# Out:
# hello world
# hello girles
# hello From group 4

# %% [markdown]
# **A major purpose of functions** is to group code that gets executed multiple times. Without a function defined, you would have to copy and paste this code each time.
#
# *  A value being passed to a function in a function call is an **argument**
# *  Variables that have arguments assigned to them are **parameters.**

# %%
#define your own functions that accept arguments
def hello(name):
  print("hello  " + name)

# %%
hello("hawaa") # t'hawaa'he arguments are stored in the parameters
hello("Group_4") # parameters is that the value stored in a parameter is forgotten when the function returns
# Out:
# hello  hawaa
# hello  Group_4

# %% [markdown]
# When creating a function using the def statement, you can specify what the return value should be with a **return statement.**

# %%
len(" group4")
# Out:
# 7

# %%
def re_turned(re_number):
  if re_number == 1 :
    return 'the number is 1'
  elif re_number == 2:
    return 'the number is 2'
  elif re_number == 3 :
    return 'the number is 3 '
  elif re_number == 4:
    return 'the number is 4'
  elif re_number == 5 :
    return 'the number is 5 '

# %%
re_turned(5)
# Out:
# 'the number is 5 '

# %%
re_turned(3)
# Out:
# 'the number is 3 '

# %% [markdown]
# **Keyword Arguments and the print() Function**
# Most arguments are identified by their position in the function call ,However, rather than through their position, **keyword arguments** are identified by the keyword put before them in the function call,**Keyword arguments** are often used for optional parameters

# %%
def name_age(name , age : int):
  print(name + ' is ' + str(age) + ' years old')

# %%
name_age('Aseda',25)
# Out:
# Aseda is 25 years old

# %%
name_age(25 , 'Asrda')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-4163099438> in <cell line: 0>()
# ----> 1 name_age(25 , 'Asrda')
#
# <ipython-input-12-3683142802> in name_age(name, age)
#       1 def name_age(name , age : int):
# ----> 2   print(name + ' is ' + str(age) + ' years old')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
name_age(age = 25 , name = 'Asrda')
# Out:
# Asrda is 25 years old

# %%
print("hello",'world')
# Out:
# hello world

# %%
print('hello','world','Group 4',sep=',')
# Out:
# hello,world,Group 4

# %% [markdown]
# **The Call Stack**
#
#
# *   The call stack is how Python remembers where to return the execution after each function call
# *   he call stack isn’t stored in a variable in your program
#
#
# *   Python handles it behind the scenes. When your program calls a function, Python creates a frame object on the top of the call stack
# *    Frame objects store the line number of the original function call so that Python can remember where to return
#
#
# *   If another function call is made, Python puts another frame object on the call stack above the other one.
# *   When a function call returns, Python removes a frame object from the top of the stack
# ![image.png](data:image/png;base64,...)

# %%
def Alice():
  print('Alice start')
  Bob()
  d()
  print(' Alice end ')
def Bob():
  print(' Bob start')
  Carol()
  print('Bob end ')
def Carol():
  print(' Carol start')
  print(' Carol end ')
def d():
  print('d start')
  print('d end ')

# %%
Alice()
# Out:
# Alice start
#  Bob start
#  Carol start
#  Carol end
# Bob end
# d start
# d end
#  Alice end

# %%
Bob()
# Out:
#  b start
# c start
# c end
# b end

# %% [markdown]
# **Local and Global Scope**
#
#
# *   Parameters and variables that are assigned in a called function are said to exist in that function’s **local scope**.
#
# *     Variables that are assigned outside all functions are said to exist in the** global scope**.
#
#
# *   A local scope is created whenever a function is called When the function returns, the local scope is destroyed
# *   List item

# %%
def spam():
  eggs = 31337
spam()
print(eggs)
# Local Variables Cannot Be Used in the Global Scope
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1667466462> in <cell line: 0>()
#       2   eggs = 31337
#       3 spam()
# ----> 4 print(eggs)
#       5 # Local Variables Cannot Be Used in the Global Scope
#
# NameError: name 'eggs' is not defined

# %%
  def spam():
      eggs = 99
  def spam2():
    print(eggs)
    print(eggs)
spam()
spam2()

  # Local Scopes Cannot Use Variables in Other Local Scopes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3313099720> in <cell line: 0>()
#       5   print(eggs)
#       6 spam()
# ----> 7 spam2()
#       8
#       9 # Local Scopes Cannot Use Variables in Other Local Scopes
#
# <ipython-input-23-3313099720> in spam2()
#       2     eggs = 99
#       3 def spam2():
# ----> 4   print(eggs)
#       5   print(eggs)
#       6 spam()
#
# NameError: name 'eggs' is not defined

# %%
def spam():
    print(eggs)
eggs = 42
spam()
print(eggs)
# Global Variables Can Be Read from a Local Scope
# Out:
# 42
# 42

# %%
#Local and Global Variables with the Same Name
def fun1():
  local = 11
  print(local)
def fun2():
  local = 22
  print(local)
local = 33
fun1()
fun2()
print(local)
# Out:
# 11
# 22
# 33

# %%
def spamm():
  global lolo
  lolo = 10
  print(lolo)



lolo = 100
spamm()
# If you ever want to modify the value stored in a global variable from in a function, you must use a global statement on that variable.
# Out:
# 10

# %% [markdown]
# **Exception Handling**
# etting an error, or exception, in your Python program means the entire program will crash. You don’t want this to happen in real-world programs. Instead, you want the program to detect errors, handle them, and then continue to run.

# %%
def spam(divideBy):
    return 42 / divideBy

print(spam(2))
print(spam(12))
print(spam(0))
print(spam(1))
# Out:
# 21.0
# 3.5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-25-1064725988> in <cell line: 0>()
#       4 print(spam(2))
#       5 print(spam(12))
# ----> 6 print(spam(0))
#       7 print(spam(1))
#
# <ipython-input-25-1064725988> in spam(divideBy)
#       1 def spam(divideBy):
# ----> 2     return 42 / divideBy
#       3
#       4 print(spam(2))
#       5 print(spam(12))
#
# ZeroDivisionError: division by zero

# %%
def spam(divideBy):
    try:
        return 42 / divideBy
    except ZeroDivisionError:
        print('Error: Invalid argument.')

print(spam(2))
print(spam(12))
print(spam(0))
print(spam(1))
# Out:
# 21.0
# 3.5
# Error: Invalid argument.
# None
# 42.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
